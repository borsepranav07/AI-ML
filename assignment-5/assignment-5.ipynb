# %% [markdown]
# # Task 1: Create a Simple Module (math_utils.py)

# %%
import math_utils

print("Using import math_utils")
print("Addition =", math_utils.add(10, 5))
print("Subtraction =", math_utils.subtract(10, 5))
print("Square =", math_utils.square(6))


print("\n-------------------------\n")


# Method 2 : Import only one function
from math_utils import square

print("Using from math_utils import square")
print("Square =", square(8))
# Out:
# Using import math_utils
# Addition = 15
# Subtraction = 5
# Square = 36
#
# -------------------------
#
# Using from math_utils import square
# Square = 64

# %%
# Import the module
import string_utils

text = "python is easy to learn"

print("Original Text :", text)

print("\nCapitalized Text :")
print(string_utils.capitalize_words(text))

print("\nReversed Text :")
print(string_utils.reverse_string(text))

print("\nTotal Words :")
print(string_utils.word_count(text))
# Out:
# Original Text : python is easy to learn
#
# Capitalized Text :
# Python Is Easy To Learn
#
# Reversed Text :
# nrael ot ysae si nohtyp
#
# Total Words :
# 5

# %% [markdown]
# # TASK - 3:

# %%
import shop_package.discount as disc

from shop_package.billing import calculate_total

import shop_package


price = 1000
discount = 10

print("Original Price :", price)
print("Price After Discount :", disc.apply_discount(price, discount))

print()

# Test flat_discount()
print("Flat Discount Price :", disc.flat_discount(price))

print()

# Test calculate_total()
prices = [100, 200, 300]

print("Prices :", prices)
print("Total Bill :", calculate_total(prices))

print()

# Test apply_tax()
total = calculate_total(prices)

print("Total After Tax :", shop_package.apply_tax(total))
# Out:
# Original Price : 1000
# Price After Discount : 900.0
#
# Flat Discount Price : 950
#
# Prices : [100, 200, 300]
# Total Bill : 600
#
# Total After Tax : 630.0
